# %%
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
recent_grads = pd.read_csv('recent-grads.csv')
print(recent_grads.iloc[0])
print(recent_grads.head(3))
print(recent_grads.tail(3))
recent_grads.describe()
# Out:
# Rank                                        1
# Major_code                               2419
# Major                   PETROLEUM ENGINEERING
# Total                                    2339
# Men                                      2057
# Women                                     282
# Major_category                    Engineering
# ShareWomen                           0.120564
# Sample_size                                36
# Employed                                 1976
# Full_time                                1849
# Part_time                                 270
# Full_time_year_round                     1207
# Unemployed                                 37
# Unemployment_rate                   0.0183805
# Median                                 110000
# P25th                                   95000
# P75th                                  125000
# College_jobs                             1534
# Non_college_jobs                          364
# ...

# %%
raw_data_count = len(recent_grads)
recent_grads = recent_grads.dropna()
cleaned_data_count = len(recent_grads)
print("num data points changed from ", raw_data_count, " to ", cleaned_data_count)
# Out:
# num data points changed from  173  to  172

# %%
recent_grads.plot(x = 'Sample_size', y ='Median', kind = 'scatter')
recent_grads.plot(x = 'Sample_size', y ='Unemployment_rate', kind = 'scatter')
recent_grads.plot(x = 'Full_time', y ='Median', kind = 'scatter')
recent_grads.plot(x = 'ShareWomen', y ='Unemployment_rate', kind = 'scatter')
recent_grads.plot(x = 'Men', y ='Median', kind = 'scatter')
recent_grads.plot(x = 'Women', y ='Median', kind = 'scatter')

# %%
recent_grads.plot(x = 'Total', y ='Median', kind = 'scatter')
recent_grads.plot(x = 'ShareWomen', y ='Median', kind = 'scatter')
recent_grads.plot(x = 'Full_time', y = 'Median', kind = 'scatter')

# %% [markdown]
# # Starting with histograms now

# %%
recent_grads['Sample_size'].plot(kind='hist', bins= 40)

# %%
recent_grads['Median'].plot(kind='hist', bins = 20)

# %%
recent_grads['Employed'].plot(kind='hist', bins = 20)

# %%
recent_grads['Full_time'].plot(kind='hist', bins = 20)

# %%
recent_grads['ShareWomen'].plot(kind='hist', bins = 20)

# %%
recent_grads['Unemployment_rate'].plot(kind='hist', bins = 20)

# %%
recent_grads['Men'].plot(kind='hist', bins = 30)

# %%
recent_grads['Women'].plot(kind='hist', bins = 30)

# %%
recent_grads['ShareWomen'].plot(kind='hist', bins = 30)

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(recent_grads[['Sample_size', 'Median']], figsize= (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f357d1d0b00>,
# ...
#       dtype=object)

# %%
scatter_matrix(recent_grads[['Sample_size', 'Median', 'Unemployment_rate']], figsize= (10,10))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f357cff5208>,
# ...
#       dtype=object)

# %% [markdown]
# # Moving on to the bar plots

# %%
recent_grads[:10].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[-10:].plot.bar(x='Major', y='ShareWomen')

# %%
recent_grads[-10:].plot.bar(x='Major', y='Unemployment_rate')

# %%
recent_grads[:10].plot.bar(x='Major', y='Unemployment_rate')
